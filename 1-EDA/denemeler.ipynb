# %%
import pandas as pd

# %%
races= pd.read_csv("races.csv")
races
# Out:
#       raceId  year  round  circuitId                    name        date  \
# 0          1  2009      1          1   Australian Grand Prix  2009-03-29
# 1          2  2009      2          2    Malaysian Grand Prix  2009-04-05
# 2          3  2009      3         17      Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3      Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4      Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...        ...                     ...         ...
# 1120    1140  2024     20         32  Mexico City Grand Prix  2024-10-27
# 1121    1141  2024     21         18    São Paulo Grand Prix  2024-11-03
# 1122    1142  2024     22         80    Las Vegas Grand Prix  2024-11-23
# 1123    1143  2024     23         78        Qatar Grand Prix  2024-12-01
# 1124    1144  2024     24         24    Abu Dhabi Grand Prix  2024-12-08
#
#           time                                                url    fp1_date  \
# ...

# %%
racess=races[["circuitId","year","name"]]
racess=racess[racess["year"] >= 2022]
racess["name"].unique()
# Out:
# array(['Bahrain Grand Prix', 'Saudi Arabian Grand Prix',
#        'Australian Grand Prix', 'Emilia Romagna Grand Prix',
#        'Miami Grand Prix', 'Spanish Grand Prix', 'Monaco Grand Prix',
#        'Azerbaijan Grand Prix', 'Canadian Grand Prix',
#        'British Grand Prix', 'Austrian Grand Prix', 'French Grand Prix',
#        'Hungarian Grand Prix', 'Belgian Grand Prix', 'Dutch Grand Prix',
#        'Italian Grand Prix', 'Singapore Grand Prix',
#        'Japanese Grand Prix', 'United States Grand Prix',
#        'Mexico City Grand Prix', 'São Paulo Grand Prix',
#        'Abu Dhabi Grand Prix', 'Qatar Grand Prix', 'Las Vegas Grand Prix',
#        'Chinese Grand Prix'], dtype=object)

# %%
circuits = {
    "Bahrain Grand Prix": 3,
    "Saudi Arabian Grand Prix": 77,
    "Australian Grand Prix": 1,
    "Emilia Romagna Grand Prix": 21,
    "Miami Grand Prix": 79,
    "Spanish Grand Prix": 4,
    "Monaco Grand Prix": 6,
    "Azerbaijan Grand Prix": 73,
    "Canadian Grand Prix": 7,
    "British Grand Prix": 9, 
    "Austrian Grand Prix": 70,
    "French Grand Prix": 34,
    "Hungarian Grand Prix": 11,
    "Belgian Grand Prix": 13,
    "Dutch Grand Prix" :  39,
    "Italian Grand Prix": 14,
    "Singapore Grand Prix": 15,
    "Japanese Grand Prix" : 22,
    "United States Grand Prix": 69,
    "Mexico City Grand Prix": 32,
    "São Paulo Grand Prix" : 18,
    "Abu Dhabi Grand Prix" : 24,
    "Qatar Grand Prix": 78,
    "Las Vegas Grand Prix": 80,
    "Chinese Grand Prix": 17,
}

# %%
racess[['circuitId', 'name']].drop_duplicates(subset='name')
# Out:
#       circuitId                       name
# 1036          3         Bahrain Grand Prix
# 1058         77   Saudi Arabian Grand Prix
# 1059          1      Australian Grand Prix
# 1060         21  Emilia Romagna Grand Prix
# 1061         79           Miami Grand Prix
# 1062          4         Spanish Grand Prix
# 1063          6          Monaco Grand Prix
# 1064         73      Azerbaijan Grand Prix
# 1065          7        Canadian Grand Prix
# 1066          9         British Grand Prix
# 1067         70        Austrian Grand Prix
# 1068         34          French Grand Prix
# 1069         11       Hungarian Grand Prix
# 1070         13         Belgian Grand Prix
# 1071         39           Dutch Grand Prix
# 1072         14         Italian Grand Prix
# 1073         15       Singapore Grand Prix
# 1074         22        Japanese Grand Prix
# 1075         69   United States Grand Prix
# 1076         32     Mexico City Grand Prix
# 1077         18       São Paulo Grand Prix
# ...

# %%
drivers=pd.read_csv("2-SQLite/data.csv")
drivers
# Out:
#       raceId  year  round  circuitId  driverId  constructorId  pit_stop_time  \
# 0        900  2014      1          1         3            131        23673.0
# 1        900  2014      1          1         3            131        24331.0
# 2        900  2014      1          1         4              6        21978.0
# 3        900  2014      1          1         4              6        22887.0
# 4        900  2014      1          1         8              6        21825.0
# ...      ...   ...    ...        ...       ...            ...            ...
# 7974    1132  2024     12          9       855             15        33083.0
# 7975    1132  2024     12          9       857              1        29200.0
# 7976    1132  2024     12          9       857              1        29541.0
# 7977    1132  2024     12          9       858              3        29444.0
# 7978    1132  2024     12          9       858              3        32801.0
#
# ...

# %%
driverss=drivers[drivers["year"] >= 2022]
driverss["driverId"].unique()
# Out:
# array([  1,   4, 807, 815, 817, 822, 825, 830, 832, 839, 840, 842, 844,
#        846, 847, 848, 849, 852, 854, 855,  20, 856, 858, 857, 859, 860],
#       dtype=int64)

# %%
driver_name= pd.read_csv("2-SQLite/drivers.csv")
driver_name
# Out:
#      driverId   driverRef number code  forename     surname         dob  \
# 0           1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...         ...    ...  ...       ...         ...         ...
# 854       856    de_vries     21  DEV      Nyck    de Vries  1995-02-06
# 855       857     piastri     81  PIA     Oscar     Piastri  2001-04-06
# 856       858    sargeant      2  SAR     Logan    Sargeant  2000-12-31
# 857       859      lawson     40  LAW      Liam      Lawson  2002-02-11
# 858       860     bearman     38  BEA    Oliver     Bearman  2005-05-08
#
#        nationality                                             url
# ...

# %%
filtered_driver=driver_name[driver_name["driverId"].isin([  1,   4, 807, 815, 817, 822, 825, 830, 832, 839, 840, 842, 844,
       846, 847, 848, 849, 852, 854, 855,  20, 856, 858, 857, 859, 860])]
filtered_driver
# Out:
#      driverId        driverRef number code   forename     surname         dob  \
# 0           1         hamilton     44  HAM      Lewis    Hamilton  1985-01-07
# 3           4           alonso     14  ALO   Fernando      Alonso  1981-07-29
# 19         20           vettel      5  VET  Sebastian      Vettel  1987-07-03
# 452       842            gasly     10  GAS     Pierre       Gasly  1996-02-07
# 807       807       hulkenberg     27  HUL       Nico  Hülkenberg  1987-08-19
# 814       815            perez     11  PER     Sergio       Pérez  1990-01-26
# 816       817        ricciardo      3  RIC     Daniel   Ricciardo  1989-07-01
# 821       822           bottas     77  BOT   Valtteri      Bottas  1989-08-28
# 824       825  kevin_magnussen     20  MAG      Kevin   Magnussen  1992-10-05
# 829       830   max_verstappen     33  VER        Max  Verstappen  1997-09-30
# 831       832            sainz     55  SAI     Carlos       Sainz  1994-09-01
# ...

# %%
drivers = {
    "Lewis Hamilton": 1,
    "Fernando Alonso": 4,
    "Sebastian Vettel": 20,
    "Pierre Gasly": 842,
    "Nico Hülkenberg": 807,
    "Sergio Pérez": 815,
    "Daniel Ricciardo": 817,
    "Valtteri Bottas": 822,
    "Max Verstappen": 830,
    "Carlos Sainz": 832,
    "Esteban Ocon": 839,
    "Lance Stroll": 840,
    "Charles Leclerc": 844,
    "Lando Norris": 846,
    "George Russell": 847,
    "Alexander Albon": 848,
    "Nicholas Latifi": 849,
    "Yuki Tsunoda": 852,
    "Mick Schumacher": 854,
    "Guanyu Zhou": 855,
    "Nyck de Vries": 856,
    "Oscar Piastri": 857,
    "Logan Sargeant": 858,
    "Liam Lawson": 859,
    "Oliver Bearman": 860,
}

# %%
constructors= pd.read_csv("2-SQLite/data.csv")
constructors
# Out:
#       raceId  year  round  circuitId  driverId  constructorId  pit_stop_time  \
# 0        900  2014      1          1         3            131        23673.0
# 1        900  2014      1          1         3            131        24331.0
# 2        900  2014      1          1         4              6        21978.0
# 3        900  2014      1          1         4              6        22887.0
# 4        900  2014      1          1         8              6        21825.0
# ...      ...   ...    ...        ...       ...            ...            ...
# 7974    1132  2024     12          9       855             15        33083.0
# 7975    1132  2024     12          9       857              1        29200.0
# 7976    1132  2024     12          9       857              1        29541.0
# 7977    1132  2024     12          9       858              3        29444.0
# 7978    1132  2024     12          9       858              3        32801.0
#
# ...

# %%
constructorss=constructors[constructors["year"]>= 2022]
constructorss["constructorId"].unique()
# Out:
# array([131, 214, 117,   9,   1,  51, 210,   6, 213,   3, 215,  15],
#       dtype=int64)
